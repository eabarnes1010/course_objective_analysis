# %% [markdown]
# # Using PCA for noise reduction (a.k.a. EOF filtering)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/eabarnes1010/course_objective_analysis/blob/main/code/eof_noise_reduction.ipynb)
#
# *Elizabeth A. Barnes — BU Earth & Environment — Last updated: 2026-05-27*
#
# ## Learning objectives
#
# - Use principal component analysis (PCA) as a low-pass filter: keep only the leading modes and reconstruct.
# - See how the reconstructed field grows smoother (and the variance retained grows) as you keep more PCs.
# - Connect "percent variance explained" to a concrete map you can look at.
#
# *Note on terminology: in the atmospheric sciences, principal components are often called "empirical orthogonal functions" (EOFs). The math is the same; this notebook uses PCA throughout.*

# %% [markdown]
# ## Setup

# %%
try:
    import google.colab

    IN_COLAB = True
except ImportError:
    IN_COLAB = False
print(f"IN_COLAB = {IN_COLAB}")
# Out:
# IN_COLAB = False

# %%
if IN_COLAB:
    # cartopy + cmocean are usually preinstalled on Colab; fall back if not.
    try:
        import cartopy  # noqa: F401
    except ImportError:
        get_ipython().system("pip install cartopy")
    try:
        import cmocean  # noqa: F401
    except ImportError:
        get_ipython().system("pip install cmocean")

import cartopy as ct
import cartopy.crs as ccrs
import cmocean
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
from cartopy.util import add_cyclic_point

mpl.rcParams["figure.dpi"] = 100

map_proj = ccrs.Robinson(central_longitude=0.0)

# %% [markdown]
# ## Globe-plotting helper
#
# A small wrapper around `ax.pcolormesh` that adds the cyclic seam at 360 degrees and draws coastlines.

# %%
def draw_on_globe(
    ax,
    data,
    lats,
    lons,
    cmap="coolwarm",
    vmin=None,
    vmax=None,
    cbar=True,
    extent="both",
):
    """Draw a 2-D lat/lon field on a cartopy axis with a cyclic seam."""
    data_cyc, lons_cyc = add_cyclic_point(data, coord=lons)
    ax.set_global()
    ax.coastlines(linewidth=1.2, color="black")
    image = ax.pcolormesh(
        lons_cyc,
        lats,
        data_cyc,
        transform=ccrs.PlateCarree(),
        cmap=cmap,
        vmin=vmin,
        vmax=vmax,
    )
    if cbar:
        cb = plt.colorbar(
            image, shrink=0.75, orientation="vertical", pad=0.02, extend=extent
        )
        cb.ax.tick_params(labelsize=6)
    else:
        cb = None
    return cb, image

# %% [markdown]
# ## Data description
#
# Two-meter monthly air temperature anomalies from the [Berkeley Earth Surface Temperature (BEST)](https://berkeleyearth.org/) dataset, 1960–2020. We subsample every fourth grid point in latitude and longitude to keep the matrices manageable, and fill missing values with zero (i.e. zero anomaly).

# %%
if IN_COLAB:
    get_ipython().system(
        "wget -q https://scc1.bu.edu/~eabarnes/class/BEST-1950-2018-monthlyTemp.nc"
    )
    filename = "BEST-1950-2018-monthlyTemp.nc"
else:
    filename = "../data/BEST-1950-2018-monthlyTemp.nc"

ds = xr.open_dataset(filename)
ds = ds.sel(time=slice("1960-01-01", "2020-01-01"))
ds = ds[{"latitude": slice(None, None, 4), "longitude": slice(None, None, 4)}]
ds = ds.fillna(0.0)
print(ds)

ds["temperature"][0].plot()
# Out:
# <xarray.Dataset> Size: 12MB
# Dimensions:      (latitude: 45, longitude: 90, time: 708, month_number: 12)
# Coordinates:
#   * latitude     (latitude) float32 180B -89.5 -85.5 -81.5 ... 78.5 82.5 86.5
#   * longitude    (longitude) float32 360B -179.5 -175.5 -171.5 ... 172.5 176.5
#   * time         (time) datetime64[ns] 6kB 1960-01-31 1960-02-29 ... 2018-12-31
# Dimensions without coordinates: month_number
# Data variables:
#     land_mask    (latitude, longitude) float64 32kB 1.0 1.0 1.0 ... 0.0 0.0 0.0
#     temperature  (time, latitude, longitude) float32 11MB -2.435 ... 2.578
#     climatology  (month_number, latitude, longitude) float32 194kB -27.5 ... ...
# Attributes:
#     CDI:                   Climate Data Interface version 1.9.2 (http://mpime...
#     history:               Mon Mar 25 14:16:12 2019: cdo seldate,1950-01-01T0...
#     institution:           Berkeley Earth Surface Temperature Project
# ...

# %% [markdown]
# ## Run PCA on the temperature field
#
# Reshape `(time, lat, lon)` into a 2-D matrix `X` of shape `(time, space)`, then take the eigendecomposition of the spatial covariance matrix $\frac{1}{N} X^T X$.

# %%
X = ds["temperature"].values
X = X.reshape(X.shape[0], X.shape[1] * X.shape[2])
X.shape
# Out:
# (708, 4050)

# %%
# Spatial covariance matrix (no NaNs at this point thanks to fillna).
C = (X.T @ X) / X.shape[0]

# Eigendecomposition; lam = eigenvalues, E = eigenvectors (columns).
lam, E = np.linalg.eig(C)

# PC time series for every mode.
Z = X @ E

# Percent variance explained per mode.
pve = 100.0 * lam / np.sum(lam)

# %% [markdown]
# ## Plotting helpers

# %%
def plot_eigenvalues(pc_keep):
    """Plot the variance-explained spectrum with North et al. error bars."""
    Nstar = X.shape[1]  # assume spatial samples are independent (debatable)
    eb = pve * np.sqrt(2.0 / Nstar)
    positions = np.arange(1, pve.size + 1)

    plt.figure()
    plt.plot(positions, pve, "o-", linewidth=1, color="black", markersize=4)
    plt.errorbar(
        positions, pve, yerr=np.abs(eb / 2), xerr=None, linewidth=1, color="black"
    )
    plt.axvline(x=pc_keep[-1] + 1.5, linestyle="--", color="k")
    plt.title(f"Variance retained = {np.sum(pve[pc_keep]):.0f}%")
    plt.xlim(-0.5, max(60.0, pc_keep[-1] + 1.5))
    plt.ylim(0, np.max(pve) * 1.02)
    plt.xlabel("PC number")
    plt.ylabel("percent variance explained (%)")
    plt.show()


def plot_reconstructed_maps(month_idx, pc_keep, X_recon):
    """Side-by-side: raw map vs. PCA-reconstructed map for one month."""
    max_val = 3.0
    lats = ds["latitude"]
    lons = ds["longitude"]

    plt.figure(figsize=(15, 4.5))

    ax = plt.subplot(1, 2, 1, projection=map_proj)
    raw = X.reshape(X.shape[0], len(lats), len(lons))[month_idx, :, :]
    draw_on_globe(
        ax, raw, lats, lons, cmap=cmocean.cm.balance, vmin=-max_val, vmax=max_val
    )
    plt.title(f"Month = {month_idx}\nRaw data", fontsize=10)

    ax = plt.subplot(1, 2, 2, projection=map_proj)
    smoothed = X_recon.reshape(X_recon.shape[0], len(lats), len(lons))[month_idx, :, :]
    if smoothed.max() < 1.0:
        max_val = smoothed.max()
    draw_on_globe(
        ax, smoothed, lats, lons, cmap=cmocean.cm.balance, vmin=-max_val, vmax=max_val
    )
    plt.title(
        f"Month = {month_idx}\n"
        f"smoothed by retaining {pc_keep[-1] + 1} of {len(pve)} PCs\n"
        f"variance explained = {np.sum(pve[pc_keep]):.0f}%",
        fontsize=10,
    )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Reconstruct from a chosen subset of PCs
#
# The two knobs to play with:
#
# - `pc_keep` — which PCs to retain when reconstructing (the maximum is the number of spatial grid points).
# - `month_to_plot` — which time slice to compare raw vs. smoothed.
#
# Try shrinking `pc_keep` to just the first few PCs and watch the reconstructed map collapse onto the dominant large-scale modes; bump it back up and the small-scale detail returns.

# %%
pc_keep = np.arange(0, 75)  # which PCs to retain (max = number of grid points)
month_to_plot = 100

plot_eigenvalues(pc_keep)

# Reconstruct X from the retained PCs only:  X_recon = Z[:, k] @ E[:, k].T
Z_keep = Z[:, pc_keep]
E_keep = E[:, pc_keep]
X_recon = Z_keep @ E_keep.T

plot_reconstructed_maps(month_to_plot, pc_keep, X_recon)
# Out:
# /usr/local/lib/python3.11/dist-packages/cartopy/io/__init__.py:242: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/110m_physical/ne_110m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %% [markdown]
# ## Wrap-up
#
# Truncating to the leading PCs is a denoising step: the discarded modes are mostly small-scale, low-variance structure that we can read as noise relative to the dominant patterns. The trade-off is sharp — keep too few PCs and you smear out real regional features; keep all of them and you recover the original field exactly (variance retained = 100%).
