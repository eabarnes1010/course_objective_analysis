# %% [markdown]
# # Significance of Spectral Peaks
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/eabarnes1010/course_objective_analysis/blob/main/code/testing_spectral_significance.ipynb)
#
# *Elizabeth A. Barnes — BU Earth & Environment — Last updated: 2026-05-22*
#
# ## Learning objectives
#
# - Construct the theoretical power spectrum of a red-noise (AR(1)) null hypothesis from its lag-1 autocorrelation.
# - Estimate a power spectrum by averaging many realizations using `scipy.signal.welch`.
# - Use an F-statistic to put a 99% confidence bound on the red-noise spectrum and identify significant peaks.

# %% [markdown]
# When you compute a power spectrum from noisy data, *some* peaks always appear by chance. To assess whether the peak is meaningful (e.g. "real") we can compare it to a null-hypothesis spectrum. Here, we use a red noise with the same lag-1 autocorrelation as the data — and only flag peaks that exceed the 99% bound.

# %%
import copy

import matplotlib.pyplot as plt
import numpy as np
import scipy.signal as sig
import scipy.stats as stats

# Figure defaults for this notebook.
plt.rcParams["figure.dpi"] = 150

rng = np.random.default_rng(seed=21)

# %% [markdown]
# ## Get your data together
#
# Set the window length `T`, the number of realizations to average, and the red-noise lag-1 autocorrelation `alpha`.

# %%
T = 256  # length of window
N = 40  # number of realizations
alpha = 0.5  # red-noise lag-one autocorrelation

# %%
# Frequencies (cycles per time step) from 0 to the Nyquist frequency.
T2 = T / 2
freq = np.arange(0.0, T2 + 1.0) / T

# %% [markdown]
# ## Construct the red-noise null hypothesis
#
# For an infinitely long AR(1) process with lag-1 autocorrelation $\alpha$, the (one-sided) power spectrum has a known closed form. Build it on our frequency grid.

# %%
rspec = []
for i in np.arange(1, T2 + 2, 1):
    rspec.append(
        (1.0 - alpha * alpha)
        / (1.0 - 2.0 * alpha * np.cos(np.pi * (i - 1.0) / T2) + alpha * alpha)
    )

# %% [markdown]
# ## Analyze your data and compare to red noise
#
# Build synthetic "observations" `x` by adding a cosine at frequency `50/256 ≈ 0.2 cycles/step` onto a red-noise series with the same `alpha`. Loop through `N` realizations, average their Welch (Hann-windowed) power spectra, and overlay the red-noise theoretical spectrum and a 99% F-statistic confidence bound.
#
# As `N` grows, the true cosine signal at 0.2 cycles/step should emerge above the 99% bound.

# %%
factor = np.sqrt(1.0 - alpha * alpha)
x = np.zeros(T)

for ir in np.arange(0, N, 1):
    # Build a single red-noise realization with a buried cosine signal.
    x = np.zeros(T)
    x[0] = x[-1] * alpha + factor * rng.standard_normal()

    for j in np.arange(1, T, 1):
        # AR(1) red noise + a cosine at 50/256 = 0.2 cycles/time step.
        x[j] = (
            x[j - 1] * alpha
            + factor * rng.standard_normal()
            + 0.55 * np.cos(2.0 * np.pi * (1.0 - 0.01 * rng.standard_normal()) * 50.0 / 256.0 * j)
        )

    # Add a constant mean to show that 'detrend=constant' in welch removes it cleanly.
    x = x + 1.0

    if ir == 0:
        plt.figure()
        plt.plot(x)
        plt.title("plot of chunk 1 of time series x(t)")
        plt.xlabel("time")
        plt.ylabel("value")
        plt.show()

    # Welch periodogram with a Hann window; detrend removes the constant we added above.
    p = sig.welch(x, window="hann", nperseg=T, detrend="constant")
    if ir == 0:
        psum = p[1]
    else:
        psum = psum + p[1]

    # Running average of the power spectrum across realizations, normalized.
    pave = psum / (ir + 1.0)
    pave = pave / np.mean(pave)

    # 99% confidence bound on red-noise spectrum via the F-distribution.
    # Degrees of freedom grow with each averaged realization.
    dof = 2.0 * (ir + 1.0)
    fstat = stats.f.ppf(0.99, dof, 1000)
    spec99 = [fstat * m for m in rspec]

    if (ir + 1.0) % 5 == 0 or ir == 0:
        plt.figure()
        plt.xlabel("frequency (cycles per time step)")
        plt.ylabel("power")
        plt.title(f"# Realizations = {ir + 1}")
        plt.ylim(0, 20.0)
        plt.xlim(0, 0.5)
        plt.plot(freq, pave, "-k", label="data")
        plt.plot(freq, rspec, "-", label="red-noise fit", color="red")
        plt.plot(freq, spec99, "--", label="99% confidence", color="red")
        plt.legend(frameon=False)

plt.show()

# %% [markdown]
# As we add more and more realizations of the data, the signal at 0.2 cycles/time step emerges from the noise and pokes above the 99% confidence bound on the red-noise null hypothesis. Realizations early on are too noisy to distinguish the cosine from random fluctuations; by `N ≈ 40` the peak is clearly significant.

# %% [markdown]
# ## Wrap-up
#
# - The theoretical AR(1) spectrum gives a closed-form null hypothesis for a red-noise process with known lag-1 autocorrelation.
# - Welch's method (windowed segments averaged together) gives a smoother spectral estimate than a single spectrum.
# - The F-statistic provides a confidence bound on the red-noise spectrum; degrees of freedom grow with the number of averaged realizations, tightening the bound and revealing weaker peaks.
